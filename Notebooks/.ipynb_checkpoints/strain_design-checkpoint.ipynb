# %%
import cobra
import cameo
import sys
sys.path.append("../Scripts")
from strain_design import add_metabolic_pathway, single_optknock
import pandas as pd

# %%
model_fn = "../Models/Sco-GEM.xml"
pathway_fn = "../Data/constructed_pathways/1.json"
folder = "../Data/constructed_pathways/"
results_folder = "../Data/knockouts"

# %%
model = cobra.io.read_sbml_model(model_fn)
# Out:
# '' is not a valid SBML 'SId'.
# Using license file C:\Users\snorres\gurobi.lic
# Academic license - for non-commercial use only

# %%
biomass_rxn_id = "BIOMASS_SCO_tRNA"
target_id = "DM_secondary_metabolite"

# %%
pathway = cobra.io.load_json_model(pathway_fn)

# %%
model.merge(pathway)
# Out:
# <Model  at 0x144384f2710>

# %%
model.objective = model.reactions.get_by_id(target_id)

# %%
model.reactions.get_by_id(biomass_rxn_id).lower_bound = 0

# %%
solution = model.optimize()
print(model.summary())
# Out:
# IN_FLUXES IN_FLUXES OUT_FLUXES OUT_FLUXES        OBJECTIVES        OBJECTIVES
#     ID       FLUX       ID        FLUX               ID               FLUX
#      o2_e     1.37     h2o_e      3.16     DM_secondary_metabolite   0.012
#  glc__D_e      0.8     co2_e      1.62                                 nan
#     nh4_e    0.437       h_e     0.563                                 nan
#      pi_e   0.0492                 nan                                 nan
# C:\Users\snorres\AppData\Local\Continuum\miniconda3\lib\site-packages\cobra\core\summary\summary.py:206: UserWarning:
#
# Setting float_format to anything other than None will cause nan to be present in the output.

# %%
ppp = cameo.phenotypic_phase_plane(model, variables = [biomass_rxn_id, target_id])

# %%
ppp.plot(points = [(solution.fluxes[biomass_rxn_id], solution.fluxes[target_id])])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-dfd49068abfc> in <module>
# ----> 1 ppp.plot(points = [(solution.fluxes[biomass_rxn_id], solution.fluxes[target_id])])
#
# c:\users\snorres\git\cameo\cameo\flux_analysis\analysis.py in plot(self, grid, width, height, title, axis_font_size, palette, points, points_colors, estimate, **kwargs)
#     838                                                   title=title, y_axis_label=y_axis_label, x_axis_label=x_axis_label,
#     839                                                   z_axis_label=z_axis_label, palette=palette, points=points,
# --> 840                                                   points_colors=points_colors)
#     841
#     842         else:
#
# c:\users\snorres\git\cameo\cameo\visualization\plotting\with_plotly.py in production_envelope_3d(self, dataframe, grid, width, height, title, points, points_colors, palette, x_axis_label, y_axis_label, z_axis_label)
#     195
#     196         if points is not None:
# --> 197             x, y, z = zip(*points)
#     198             scatter = go.Scatter3d(x=x, y=y, z=z, mode="markers", name="Data Points",
#     199                                    marker=dict(color="green" if points_colors is None else points_colors))
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
ppp.data_frame.plot(biomass_rxn_id, "objective_upper_bound", kind = "scatter")

# %% [markdown]
# # OptKnock

# %%
from cameo.strain_design import OptKnock

# %%
model.objective = model.reactions.get_by_id(biomass_rxn_id)
max_growth = model.slim_optimize()
fraction_of_optimum = 0.1
model.reactions.get_by_id(biomass_rxn_id).lower_bound = max_growth*fraction_of_optimum
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-85-00f4b55402b7> in <module>
# ----> 1 model.objective = model.reactions.get_by_id(biomass_rxn_id)
#       2 max_growth = model.slim_optimize()
#       3 fraction_of_optimum = 0.1
#       4 model.reactions.get_by_id(biomass_rxn_id).lower_bound = max_growth*fraction_of_optimum
#
# ~\AppData\Local\Continuum\miniconda3\lib\site-packages\cobra\core\dictlist.py in get_by_id(self, id)
#      56     def get_by_id(self, id):
#      57         """return the element with a matching id"""
# ---> 58         return list.__getitem__(self, self._dict[id])
#      59
#      60     def list_attr(self, attribute):
#
# KeyError: 'BIOMASS_SCO_tRNA'

# %%
#model = models.bigg.iJO1366
model.solver = "gurobi"
optknock = OptKnock(model, fraction_of_optimum=0.1)
# Out:
# Read LP format model from file C:\Users\snorres\AppData\Local\Temp\tmpkpiiyp23.lp
# Reading time = 0.03 seconds
# : 2073 rows, 5224 columns, 22724 nonzeros

# %%
result = optknock.run(max_knockouts=1, target="EX_ac_e", biomass="BIOMASS_SCO")

# %%
OptKnock??

# %%
cobra.flux_analysis.find_blocked_reactions(model)
# Out:
# ['11OXPENT',
#  '1P4H2CDA',
#  '23DHBZS',
#  '23LGALAC',
#  '23PDE2e',
#  '23PDE4e',
#  '23PDE7e',
#  '23PDE9e',
#  '24DCLPMO',
#  '24DCOAR',
#  '24DHX5M6OI',
#  '25DBUT',
#  '2A3MUCSD',
#  '2ABZMOx',
#  '2ABZMOy',
#  '2AMUCSAD',
#  '2CLRED',
#  '2D3DGLUCDH',
#  '2DHGLCK',
#  '2FURAPS',
#  '2K3DRHAM',
#  '2OGLUAH',
#  '2OH3EDISO',
#  '2OXOADOX',
#  '36AHDGALC',
#  '38DPCLOR',
#  '3AIBUTS',
#  '3CLBZADH',
#  '3CLBZDH',
#  '3CTHPPT',
#  '3DM4HXPPO',
#  '3DMA4HMO',
#  '3HAD170',
#  '3HAD180',
#  '3HAD181',
#  '3HADi180',
#  '3HCINNMH',
#  '3HPPPNH',
#  '3HXACOADH',
#  '3HXKYN',
#  '3K5AHC',
#  '3MBZALDH',
#  '3MBZDH',
#  '3NTD2e',
#  '3NTD4e',
#  '3NTD7e',
#  '3NTD9e',
#  '3OAR170',
#  '3OAR180',
#  '3OAR181',
#  '3OARi180',
#  '3OAS170',
#  '3OAS180',
#  '3OAS181',
#  '3OASi180',
#  '3OCHOCDH',
#  '3OXCOADH',
#  '3OXOR',
#  '3T3LPROD',
#  '44DPCDH',
#  '45DOPA',
#  '45SDOPs',
#  '4C4HX2OA',
#  '4CMCOAS',
#  '4COXADH',
#  '4HDAPMO',
#  '4HGLSD',
#  '4HPROOR',
#  '4HTHRS',
#  '4HXBOPT',
#  '4HXPUHBT',
#  '4HYBUT',
#  '4HYDPRO',
#  '4IP7MO2H__R',
#  '4IP7MO2H__S',
#  '4IZPHYDs',
#  '4MBZALDH',
#  '4MBZDH',
#  '4NIPHOM',
#  '4NITROB',
#  '4OT',
#  '4PCP',
#  '4SBZADH',
#  '4SULFADH',
#  '5CM2HMUCI',
#  '5METDA',
#  '5OP3TCCL',
#  '6HEXHYD',
#  'AAAHYD',
#  'AAMYLe',
#  'AATA',
#  'AATC',
#  'ABTDG',
#  'AC1MO',
#  'ACACT3r',
#  'ACACT4r',
#  'ACACT5r',
#  'ACACT7r',
#  'ACACT8r',
#  'ACCAHh',
#  'ACETDH',
#  'ACITRULD',
#  'ACM6PH',
#  'ACNMS',
#  'ACOAD3f',
#  'ACOAD4f',
#  'ACOAD5f',
#  'ACOAD6f',
#  'ACOAD7f',
#  'ACOAD8f',
#  'ACON6LAT',
#  'ACPPAT170',
#  'ACPPAT180',
#  'ACPPAT181',
#  'ACPPATi180',
#  'ACRCOAR',
#  'ACTCOAT2',
#  'ADAPAT',
#  'ADPRDP',
#  'ADPT2',
#  'AGM4PCP',
#  'AGMDA',
#  'AGMT',
#  'AGPAT120',
#  'AGPAT141',
#  'AGPAT170',
#  'AGPAT180',
#  'AGPAT181',
#  'AGPATi180',
#  'AHLGAL',
#  'AHLGALb',
#  'AHSERL2',
#  'ALALAC',
#  'AM4PCP',
#  'AMBACS',
#  'AMBCOAL',
#  'AMID',
#  'AMID3',
#  'AMID5',
#  'AMPTASECG',
#  'AMPTASEPG',
#  'ANHMK',
#  'AP2EISOs',
#  'APATT',
#  'APCS',
#  'APG3PAT120',
#  'APG3PAT141',
#  'APG3PAT170',
#  'APG3PAT180',
#  'APG3PAT181',
#  'APG3PATi180',
#  'APH140',
#  'APH150',
#  'APH160',
#  'APH161',
#  'APH170',
#  'APH180',
#  'APH181',
#  'APHai150',
#  'APHai170',
#  'APHi140',
#  'APHi150',
#  'APHi160',
#  'APHi170',
#  'APHi180',
#  'ARABDH',
#  'ARABISOs',
#  'ARABLAC',
#  'ARAI',
#  'ARAT',
#  'ARUH',
#  'ASCISOs',
#  'ASCOROX',
#  'ASCORPO',
#  'ASR',
#  'BACCL',
#  'BACCL2',
#  'BALDHs',
#  'BCOADH',
#  'BETALDHx',
#  'BETALDHy',
#  'BFORCL',
#  'BGLA',
#  'BMMCOAL',
#  'BMOCOS',
#  'BMOGDS1',
#  'BMOGDS2',
#  'BSUZCOAD',
#  'BTAOR',
#  'BTCOAR',
#  'BUPN',
#  'BWCOGDS1',
#  'BWCOGDS2',
#  'BWCOS',
#  'BZALDH',
#  'BZDH',
#  'BZSCT',
#  'C7AHXDH',
#  'CAFFCOA',
#  'CARBMODH',
#  'CARBPHOL',
#  'CARNMOx',
#  'CARNMOy',
#  'CARNOX',
#  'CAT23DOX',
#  'CBIAT',
#  'CBLAT',
#  'CBMD',
#  'CDP4DGNOx',
#  'CDP4DGNOy',
#  'CEPSPORDA',
#  'CHO43OR',
#  'CHOLD',
#  'CHOLD2',
#  'CHOLOX',
#  'CINNCOAL',
#  'CINNDOX',
#  'CLADHAL',
#  'CLPNS120',
#  'CLPNS141',
#  'CLPNS170',
#  'CLPNS180',
#  'CLPNS181',
#  'CLPNSII120',
#  'CLPNSII141',
#  'CLPNSII170',
#  'CLPNSII180',
#  'CLPNSII181',
#  'CLPNSIIi180',
#  'CLPNSi180',
#  'CMCMSAD',
#  'CMPA',
#  'COBP3DH',
#  'CODSCL5BMT',
#  'CODSCL5DA',
#  'COSPERDH',
#  'CPC2MT',
#  'CPC3MT',
#  'CPC6R',
#  'CPC8MM',
#  'CREATA',
#  'CREATDA',
#  'CSPMDDH',
#  'CTECOAI7',
#  'CTECOAI8',
#  'CTPGNAC',
#  'CU1O',
#  'CUMALDH',
#  'CYANST',
#  'CYC1CCDH',
#  'CYCHEXDH',
#  'CYCHEXMO',
#  'CYCHEX_2',
#  'CYCOADH',
#  'CYRDAS',
#  'CYSBLY',
#  'CYT5MONP',
#  'DABAACT',
#  'DABAAT',
#  'DARGO',
#  'DASYN120',
#  'DASYN141',
#  'DASYN170',
#  'DASYN180',
#  'DASYN181',
#  'DASYNi180',
#  'DATPHs',
#  'DCH',
#  'DCPEPFU',
#  'DCYCHEX',
#  'DCYTD',
#  'DDALLO',
#  'DDGALK',
#  'DDGLK',
#  'DDPGA',
#  'DGALACYC',
#  'DGC2D',
#  'DGLUC4KR',
#  'DGLUCMT',
#  'DGLUCYC',
#  'DGLYHRED',
#  'DHACOAH',
#  'DHBD',
#  'DHBS',
#  'DHICONF',
#  'DHNPTE',
#  'DHPD',
#  'DHYDTHYM',
#  'DIFRNLY',
#  'DMETMO',
#  'DMT',
#  'DORNO',
#  'DPCOX',
#  'DPMSYN',
#  'DPROLORED',
#  'DRBK',
#  'DRIB2FUR',
#  'DRIBPA',
#  'DTARTD',
#  'DTDP26DGR',
#  'DTDPG4E',
#  'DXYLDH',
#  'DXYLK',
#  'E4PD',
#  'EAR170x',
#  'EAR170y',
#  'EAR180x',
#  'EAR180y',
#  'EAR181x',
#  'EAR181y',
#  'EARi180x',
#  'EARi180y',
#  'ECOAH3',
#  'ECOAH4',
#  'ECOAH5',
#  'ECOAH7',
#  'ECOAH8',
#  'ECTH',
#  'ECTS',
#  'EDA',
#  'EHGLAT',
#  'EMCCCM',
#  'EME',
#  'EN6LNOR',
#  'EPMGH',
#  'ETHAAL',
#  'EX_cellul_e',
#  'EX_xylan_e',
#  'FALDH2',
#  'FALDH3',
#  'FALGTHLs',
#  'FARNDPPS',
#  'FBA4',
#  'FCLPA',
#  'FENTON',
#  'FESD2s',
#  'FHL',
#  'FLAVMO',
#  'FMETTRS',
#  'FORCT',
#  'FORGLUIH',
#  'FORHOPS',
#  'FRUISOs',
#  'FUMAH',
#  'G1PCTYT',
#  'G1PTT',
#  'GADECARB',
#  'GAL6PI',
#  'GALACDH',
#  'GALCTD',
#  'GALCTND',
#  'GALIGH',
#  'GALKr',
#  'GALM2',
#  'GALOO',
#  'GALS3',
#  'GALURDH',
#  'GCGBGE',
#  'GCGUAIDH',
#  'GCL',
#  'GDCARBM',
#  'GDP64HRD',
#  'GDPMANDH',
#  'GERDH',
#  'GERISOs',
#  'GF4GL_0',
#  'GF4GL_1',
#  'GGGABADH',
#  'GGHCSH',
#  'GGLACOX',
#  'GGLGH',
#  'GGLUPUT',
#  'GHBDHy',
#  'GLCATr',
#  'GLCRD',
#  'GLCRD2',
#  'GLNLASE',
#  'GLUCORDH',
#  'GLULACIs',
#  'GLYAT',
#  'GLYOX',
#  'GMAND',
#  'GMGGDCAP',
#  'GMHEPAT',
#  'GPDDA1',
#  'GPDDA1e',
#  'GPDDA2',
#  'GPDDA2e',
#  'GPDDA3',
#  'GPDDA3e',
#  'GPDDA4',
#  'GPDDA4e',
#  'GPDDA5',
#  'GPDDA5e',
#  'GTHPi',
#  'GTHRDH',
#  'GTPCIII2',
#  'GUDBUTNAH',
#  'GUL14LACDH',
#  'GUL5DH',
#  'HACD3',
#  'HACD4',
#  'HACD5',
#  'HACD7',
#  'HACD8',
#  'HADPCOADH3',
#  'HBZOPT',
#  'HDXSQLS',
#  'HEP7PHOK',
#  'HERCOX',
#  'HEX4',
#  'HEXHYD',
#  'HKYNH',
#  'HMMSHALDs',
#  'HMSD',
#  'HOPNTAL3',
#  'HPHL',
#  'HPROb',
#  'I3PYRMO',
#  'IPAXYL',
#  'KHK2',
#  'LACZ',
#  'LADGMDH',
#  'LALDD2',
#  'LAURAT',
#  'LCADi',
#  'LCYB',
#  'LCYG',
#  'LGALACD',
#  'LHISTMT',
#  'LIPAMPL',
#  'LIPATPT',
#  'LLYXDH',
#  'LPFPLT',
#  'LPPGS',
#  'LYS6MO',
#  'LYXI',
#  'LYXID',
#  'L_LACD4',
#  'MACPAL',
#  'MAHYD',
#  'MALCOAMT',
#  'MALEI',
#  'MALPYRISO',
#  'MALTATr',
#  'MAN1PPP',
#  'MAN6PI',
#  'MANISOs',
#  'MCPST',
#  'MCPST2',
#  'MCSNAH',
#  'MCTP1B',
#  'MCTP2A',
#  'MDDCP2',
#  'MDDCP5',
#  'MDDEP2',
#  'MDDEP4',
#  'MECDPDH5_2',
#  'MELTGH',
#  'METB1',
#  'MGLYXOX',
#  'MGSDGS',
#  'MHPGLUT',
#  'MLTG1',
#  'MLTG1e',
#  'MLTG2e',
#  'MLTG3e',
#  'MLTG4e',
#  'MLTG5e',
#  'MMSAD1',
#  'MMSYNA',
#  'MMSYNB',
#  'MMYSYN1',
#  'MMYSYN2',
#  'MMYSYN3',
#  'MNLDH2',
#  'MNNH',
#  'MPAHYD',
#  'MPML',
#  'MPTG2',
#  'MSUCOADH',
#  'MTAP',
#  'MTBUTEMO',
#  'MTRI',
#  'MYCARSL',
#  'MYCFORM',
#  'NAACPHYD',
#  'NABTNO',
#  'NADPHXD',
#  'NADPHXE',
#  'NHHAAH',
#  'NICMO',
#  'NODOx',
#  'NODOy',
#  'NOR_syn',
#  'NSHDDS',
#  'NTD12e',
#  'NTD1e',
#  'NTD3e',
#  'NTD4e',
#  'NTD5e',
#  'NTD6e',
#  'NTD7e',
#  'NTD8e',
#  'NTD9e',
#  'NTPP10',
#  'NTRIR2x',
#  'NTRIR2y',
#  'O426ISO',
#  'O4OXOCYR',
#  'OCTNLL',
#  'OHPBAT',
#  'ONTROOXR',
#  'OP4ENH3',
#  'OPHBDC',
#  'ORNHYDXx',
#  'ORNHYDXy',
#  'OXCDC',
#  'OXDHCOAT',
#  'P2OLDH',
#  'P4CADH',
#  'PACCOAE',
#  'PAPA141',
#  'PAPA170',
#  'PAPA180',
#  'PAPA181',
#  'PAPAi180',
#  'PCFO',
#  'PDH4',
#  'PDHe3hr',
#  'PDX5POi',
#  'PENAM',
#  'PFK_2',
#  'PGLYCP',
#  'PGSA120',
#  'PGSA140',
#  'PGSA141',
#  'PGSA150',
#  'PGSA160',
#  'PGSA161',
#  'PGSA170',
#  'PGSA180',
#  'PGSA181',
#  'PGSAai150',
#  'PGSAai170',
#  'PGSAi140',
#  'PGSAi150',
#  'PGSAi160',
#  'PGSAi170',
#  'PGSAi180',
#  'PHCD',
#  'PHCHGS',
#  'PHYFLUDS',
#  'PHYSYN',
#  'PHYTDES',
#  'PHYTES',
#  'PICDDHs',
#  'PINOS120',
#  'PINOS141',
#  'PINOS170',
#  'PINOS180',
#  'PINOS181',
#  'PINOSi180',
#  'PKBBS',
#  'PMANM',
#  'POR_1',
#  'PPNAD2OR',
#  'PPPNDO',
#  'PPTRIAT',
#  'PPTSERDC',
#  'PRODSYN',
#  'PROLRM',
#  'PROP2MO',
#  'PSD120',
#  'PSD141',
#  'PSD170',
#  'PSD180',
#  'PSD181',
#  'PSDi180',
#  'PSSA120',
#  'PSSA141',
#  'PSSA170',
#  'PSSA180',
#  'PSSA181',
#  'PSSAi180',
#  'PTC6MT',
#  'PTLACS',
#  'PTRCAT1',
#  'PU5PG',
#  'PYACOADH',
#  'PYDAMK',
#  'PYDXK',
#  'PYDXNK',
#  'PYDXOR',
#  'QUINHYDs',
#  'RAFGH',
#  'RBK_L1',
#  'RBP4E',
#  'RBTDG',
#  'RE0691C',
#  'REDS35b',
#  'REPHACCOAI',
#  'RHAMFs',
#  'RIB1MPTS',
#  'RMI',
#  'RMK',
#  'RMPA',
#  'S2FE2ST',
#  'S7PI',
#  'SALOR',
#  'SAMAAT',
#  'SAMAT',
#  'SARCOX',
#  'SCB11',
#  'SCB12',
#  'SCB13',
#  'SCB14',
#  'SCB15',
#  'SCB21a',
#  'SCB21b',
#  'SCB22',
#  'SCB23',
#  'SCB24',
#  'SCB25',
#  'SCB31',
#  'SCB32',
#  'SCB33',
#  'SCB34',
#  'SCB35',
#  'SHCHCC',
#  'SLD',
#  'SORB6PP',
#  'SORBDH',
#  'SQLCYC2',
#  'SSBUTDH',
#  'STACHGALACT',
#  'STRP6K',
#  'SUCOAICT',
#  'SUCR',
#  'SULFPDH',
#  'TAG6ISOs',
#  'TAGS120',
#  'TAGS141',
#  'TAGS170',
#  'TAGS180',
#  'TAGS181',
#  'TAGSi180',
#  'TAUDO',
#  'TBFORMD',
#  'TCLBZRED',
#  'TDPDRE',
#  'TDPDRR',
#  'TDPGDH',
#  'TGBPA',
#  'THFGLUS',
#  'THPAT',
#  'THPICHYDs',
#  'THRA2i',
#  'THRD',
#  'TMDK1',
#  'TMDPP',
#  'TMETMO',
#  'TMK',
#  'TOLOR',
#  'TRYP2MO',
#  'TRYPYRAT',
#  'TYRMO',
#  'UAAGLS2',
#  'UACMAMO',
#  'UDPAGACA',
#  'UDPAMALA',
#  'UDPGD',
#  'UDPGDC',
#  'ULA4NFT',
#  'UM4PCP',
#  'UNDCAPPT',
#  'UNDEGLCT',
#  'UPPDC2',
#  'VNDH',
#  'VNTDM',
#  'X5PL3E',
#  'XGLCOLIG',
#  'XLLGXYL',
#  'XLXG',
#  'XYLI1',
#  'XYLK',
#  'XYLLAC',
#  'XYLTO',
#  'ZCARDS',
#  'ZCAROTDH2',
#  'r0163',
#  'r0686',
#  '14GLUCANabc',
#  '2HXMPt6',
#  'ABTabc',
#  'ABUTt2r',
#  'ACGApts',
#  'ALAALAabc',
#  'ARGAGMt7',
#  'ASPabc',
#  'ASPt2_2',
#  'ASPt2r',
#  'BALAt2',
#  'BTNt2i',
#  'CELLBabc',
#  'CELLUL_DEGe',
#  'CHLabc',
#  'CHLt2',
#  'CHTBSabc',
#  'CHTNDG',
#  'DADNt2',
#  'DALAt2r',
#  'DAPLLabc',
#  'DAPabc',
#  'DARBabc',
#  'DCYTt2',
#  'DDGLCNt2r',
#  'DGSNt2',
#  'DINSt2',
#  'DRIBt',
#  'DSERt2',
#  'DURIt2',
#  'ENTERt',
#  'EPMt2',
#  'ETHAt2',
#  'FRUpts',
#  'FRUpts2',
#  'GALCTNt2',
#  'GALIt2',
#  'GALabc',
#  'GALt2',
#  'GALt4',
#  'GAMpts',
#  'GGLt2',
#  'GLCRt2r',
#  'GLNabc',
#  'GLYBabc',
#  'GLYBt2r',
#  'GSNt2',
#  'INOSTt4',
#  'LALADGLUt',
#  'LCTSabc',
#  'LIPOt2',
#  'LYXDabc',
#  'LYXabc',
#  'LYXt2',
#  'L_LACt2r',
#  'MALTHXabc',
#  'MALTPTabc',
#  'MALTTRabc',
#  'MALTTTRabc',
#  'MALTabc',
#  'MALTpts',
#  'MALTt1r',
#  'MANpts',
#  'MANt2',
#  'MELIBt2',
#  'MELTt2',
#  'METabc',
#  'MNLabc',
#  'MNLpts',
#  'N2Ot',
#  'NACt',
#  'NMNP',
#  'NO3R2',
#  'NOt',
#  'OROTt2_2',
#  'PNTOt4',
#  'PTRCabc',
#  'PTRCt2',
#  'PYDAMt',
#  'PYDXNt',
#  'PYDXt',
#  'RAFFINt2',
#  'REDt',
#  'RIBabc',
#  'RMNabc',
#  'RMNt',
#  'SALCpts',
#  'SBTabc',
#  'SBTpts',
#  'SCB1t',
#  'SCB2t',
#  'SCB3t',
#  'SKMt2',
#  'SUCRabc',
#  'TAURabc',
#  'THMDt2',
#  'TREabc',
#  'TREpts',
#  'TUNGSabc',
#  'VANK',
#  'XYLAN_DEGe',
#  'XYLTabc',
#  'XYLabc',
#  'XYLt2',
#  'tcaABC',
#  'DM_2hymeph_c',
#  'DM_aacald_c',
#  'DM_ectoine__L_c',
#  'DM_mmyA_c',
#  'DM_mmyB_c',
#  'EX_14glucan_e',
#  'EX_1Dgali_e',
#  'EX_23camp_e',
#  'EX_23ccmp_e',
#  'EX_23cgmp_e',
#  'EX_23cump_e',
#  'EX_26dap_LL_e',
#  'EX_26dap__M_e',
#  'EX_2ddglcn_e',
#  'EX_3amp_e',
#  'EX_3cmp_e',
#  'EX_3gmp_e',
#  'EX_3ump_e',
#  'EX_4abut_e',
#  'EX_LalaDglu_e',
#  'EX_abt__D_e',
#  'EX_acgam_e',
#  'EX_agm_e',
#  'EX_ala_B_e',
#  'EX_ala__D_e',
#  'EX_alaala_e',
#  'EX_amp_e',
#  'EX_arab__D_e',
#  'EX_arab__L_e',
#  'EX_aso3_e',
#  'EX_asp__L_e',
#  'EX_btn_e',
#  'EX_cd2_e',
#  'EX_cellb_e',
#  'EX_chol_e',
#  'EX_chtbs_e',
#  'EX_cmp_e',
#  'EX_coelichelin_e',
#  'EX_cu_e',
#  'EX_dad_2_e',
#  'EX_damp_e',
#  'EX_dcmp_e',
#  'EX_dcyt_e',
#  'EX_desferrioxamB_e',
#  'EX_dgmp_e',
#  'EX_dgsn_e',
#  'EX_dimp_e',
#  'EX_din_e',
#  'EX_drib_e',
#  'EX_dtmp_e',
#  'EX_dump_e',
#  'EX_duri_e',
#  'EX_epm_e',
#  'EX_etha_e',
#  'EX_feroxB_e',
#  'EX_ferricoelichelin_e',
#  'EX_fru_e',
#  'EX_g3pc_e',
#  'EX_g3pe_e',
#  'EX_g3pg_e',
#  'EX_g3pi_e',
#  'EX_g3ps_e',
#  'EX_gal_e',
#  'EX_galctn__D_e',
#  'EX_gam_e',
#  'EX_ggl_e',
#  'EX_glcr_e',
#  'EX_gln__L_e',
#  'EX_glyb_e',
#  'EX_glyc3p_e',
#  'EX_gmp_e',
#  'EX_gsn_e',
#  'EX_inost_e',
#  'EX_lac__L_e',
#  'EX_lcts_e',
#  'EX_lipoate_e',
#  'EX_lyx__D_e',
#  'EX_lyx__L_e',
#  'EX_malt_e',
#  'EX_malthp_e',
#  'EX_malthx_e',
#  'EX_maltpt_e',
#  'EX_malttr_e',
#  'EX_maltttr_e',
#  'EX_man_e',
#  'EX_melib_e',
#  'EX_melt_e',
#  'EX_met__L_e',
#  'EX_mnl_e',
#  'EX_n2o_e',
#  'EX_na1_e',
#  'EX_nac_e',
#  'EX_nmn_e',
#  'EX_no2_e',
#  'EX_no3_e',
#  'EX_no_e',
#  'EX_orot_e',
#  'EX_pnto__R_e',
#  'EX_ptrc_e',
#  'EX_pydam_e',
#  'EX_pydx_e',
#  'EX_pydxn_e',
#  'EX_raffin_e',
#  'EX_rib__D_e',
#  'EX_rmn_e',
#  'EX_salcn_e',
#  'EX_sbt__D_e',
#  'EX_ser__D_e',
#  'EX_skm_e',
#  'EX_sucr_e',
#  'EX_tartr__D_e',
#  'EX_taur_e',
#  'EX_thm_e',
#  'EX_thym_e',
#  'EX_thymd_e',
#  'EX_tre_e',
#  'EX_tungs_e',
#  'EX_vanlt_e',
#  'EX_xyl__D_e',
#  'EX_xylt_e',
#  'ASCpts',
#  'BTNt',
#  'CHLNAt1',
#  'Cyt',
#  'DESabc',
#  'ENTBACTINt',
#  'EX_TPP_e',
#  'EX_asc6p_e',
#  'EX_ascb__L_e',
#  'EX_cy_e',
#  'EX_des_e',
#  'EX_entbactin_e',
#  'EX_fb_e',
#  'EX_fentero_e',
#  'EX_ficytc_e',
#  'EX_fucose_e',
#  'EX_fus_e',
#  'EX_glucs_e',
#  'EX_gthox_e',
#  'EX_hemeO_e',
#  'EX_indig_e',
#  'EX_lps_e',
#  'EX_mmyA_e',
#  'EX_mmyB_e',
#  'EX_omycin_e',
#  'EX_oxformate_e',
#  'EX_phis__L_e',
#  'EX_prn_e',
#  'EX_sufbcd_2fe2s2_e',
#  'EX_sufbcd_4fe4s_e',
#  'EX_tel_e',
#  'EX_telu_e',
#  'EX_xylb_e',
#  'FBae1',
#  'FENTEROabc',
#  'FICYTabc',
#  'FUCOSEt',
#  'FUSt',
#  'GLUCSabc',
#  'GTHOXabc',
#  'HEMabc',
#  'HISpep',
#  'INDIGt',
#  'LCTSt',
#  'LPSabc',
#  'MELIBabc',
#  'MMYAt',
#  'MMYBt',
#  'OMYCINabc',
#  'OXOFORMATEt',
#  'PRNt',
#  'RAFFINabc',
#  'SUFBCD4abc',
#  'SUFBCDabc',
#  'TELUt',
#  'TELt',
#  'TPPt',
#  'XYLBabc']

# %%
model.objective = model.reactions.get_by_id(target_id)
print(model.optimize("maximize"))
model.reactions.BIOMASS_SCO_tRNA.flux
# Out:
# <Solution 0.033 at 0x1445d974b70>
# 0.007419424698476719

# %%
df = pd.DataFrame([[1,2],[3,4]])
df.columns = ["A", "B"]
df
# Out:
#    A  B
# 0  1  2
# 1  3  4

# %%
df.sort_values("A",ascending=False).iloc[0:2,:]
d
# Out:
#      A    B    0
# 0  1.0  2.0  NaN
# 1  3.0  4.0  NaN
# A  NaN  NaN  1.0
# B  NaN  NaN  2.0

# %%
df.append(df.loc[0, :])
# Out:
#    A  B
# 0  1  2
# 1  3  4
# 0  1  2

# %% [markdown]
# # Optgene

# %%
from cameo.strain_design import OptGene
from cameo import models

# %%
model = models.bigg.iJO1366

# %%
optgene = OptGene(model)

# %%
result = optgene.run(target=model.reactions.get_by_id("EX_ac_e"),
                     #biomass=model.reactions.get_by_id(biomass_rxn_id),
                     biomass=model.reactions.BIOMASS_Ec_iJO1366_core_53p95M,
                     substrate=model.metabolites.glc__D_e,
                     max_evaluations=500,
                     plot=False)
# Out:
# Starting optimization at Wed, 16 Sep 2020 13:09:23
#   <div class="bk-root" id="4cc2d9f6-a679-49ad-8cc1-e1a05c4d7444" data-root-id="1291"></div>
# C:\Users\snorres\AppData\Local\Continuum\miniconda3\lib\site-packages\bokeh\models\sources.py:173: BokehUserWarning:
#
# ColumnDataSource's columns must be of the same length. Current lengths: ('x', 1), ('y', 0)
# HBox()
# C:\Users\snorres\AppData\Local\Continuum\miniconda3\lib\site-packages\bokeh\models\sources.py:173: BokehUserWarning:
#
# ColumnDataSource's columns must be of the same length. Current lengths: ('x', 2), ('y', 1)
# Finished after 00:01:57
# C:\Users\snorres\AppData\Local\Continuum\miniconda3\lib\site-packages\bokeh\models\sources.py:173: BokehUserWarning:
#
# ColumnDataSource's columns must be of the same length. Current lengths: ('x', 3), ('y', 2)

# %%
result
# Out:
#         <h3>OptGene Result</h3>
#         <ul>
#             <li>Simulation: fba<br/></li>
#             <li>Objective Function: $$bpcy = \frac{(BIOMASS\_SCO * EX\_ac\_e)}{EX\_glc\_\_D\_e}$$<br/></li>
#         </ul>
#         <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>reactions</th>
#       <th>genes</th>
#       <th>size</th>
#       <th>fva_min</th>
#       <th>fva_max</th>
#       <th>target_flux</th>
#       <th>biomass_flux</th>
#       <th>yield</th>
#       <th>fitness</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# </div>

# %%
model.reactions.EX_succ_e
# Out:
# <Reaction EX_succ_e at 0x1444c0f00b8>
